# %% [markdown]
# 5 Public Datasets (Kaggle / UCI)

# %% [markdown]
# 1) Iris Dataset
# *   Type:Classification
# *   Source: UCI
# *   Use:Predict Flower species based on petal/sepal size.
# 2) Titanic Dataset
# *   Type:classification
# *   Source:Kaggle
# *   use:predict survival of passengers.
# 3)  House price  Dataset
# *   Type:Regression
# *   Source:Kaggle
# *   use:predict house prices using fetures like location,size,rooms.
# 4) Titanic Dataset
# *   Type:classification/regression
# *   Source:UCI
# *   Use:predict wine quality based on chemical properties.
# 5) Titanic Dataset
# *   Type:classification
# *   Source:Kaggle/UCI
# *   Use:predict whether a person has diabetes using medical details.
